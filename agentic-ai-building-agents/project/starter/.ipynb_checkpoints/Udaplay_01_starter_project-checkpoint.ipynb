# %% [markdown]
# # [STARTER] Udaplay Project

# %% [markdown]
# ## Part 01 - Offline RAG
#
# In this part of the project, you'll build your VectorDB using Chroma.
#
# The data is inside folder `project/starter/games`. Each file will become a document in the collection you'll create.
# Example.:
# ```json
# {
#   "Name": "Gran Turismo",
#   "Platform": "PlayStation 1",
#   "Genre": "Racing",
#   "Publisher": "Sony Computer Entertainment",
#   "Description": "A realistic racing simulator featuring a wide array of cars and tracks, setting a new standard for the genre.",
#   "YearOfRelease": 1997
# }
# ```

# %% [markdown]
# ### Setup

# %%
# Only needed for Udacity workspace

import importlib.util
import sys

# Check if 'pysqlite3' is available before importing
if importlib.util.find_spec("pysqlite3") is not None:
    import pysqlite3
    sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')

# %%
import os
import json
import chromadb
from chromadb.utils import embedding_functions
from dotenv import load_dotenv
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-561d46dff789> in <module>()
#       2 import json
#       3 import chromadb
# ----> 4 from chromadb.utils import embedding_functions
#       5 from dotenv import load_dotenv
#
# ImportError: No module named 'chromadb.utils'

# %%
# TODO: Create a .env file with the following variables
# OPENAI_API_KEY="YOUR_KEY"
# CHROMA_OPENAI_API_KEY="YOUR_KEY"
# TAVILY_API_KEY="YOUR_KEY"

# %%
# TODO: Load environment variables
load_dotenv()

openai_api_key = os.getenv('OPENAI_API_KEY')
tavily_api_key = os.getenv('TAVILY_API_KEY') 
chroma_openai_api_key = os.getenv('CHROMA_OPENAI_API_KEY')

for key in [openai_api_key, tavily_api_key, chroma_openai_api_key]:
    assert key is not None
    print(key)
# Out:
# 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
# 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
# YOUR_KEY

# %% [markdown]
# ### VectorDB Instance

# %%
# TODO: Instantiate your ChromaDB Client
# Choose any path you want
chroma_client = chromadb.PersistentClient(path="chromadb")

# %% [markdown]
# ### Collection

# %%
# TODO: Pick one embedding function
# If picking something different than openai, 
# make sure you use the same when loading it
embedding_fn_0 = embedding_functions.OpenAIEmbeddingFunction(
    api_key=openai_api_key,
    model_name="text-embedding-3-small"
)
embedding_fn = embedding_functions.DefaultEmbeddingFunction()

# print(embedding_fn_0(['hola']))
print(embedding_fn(['hola']))
# Out:
# [array([-6.51595369e-02,  9.27440152e-02, -2.62070056e-02, -1.60606522e-02,
#        -6.03321306e-02, -9.46351364e-02,  1.34342074e-01, -6.57582283e-02,
#        -4.18297127e-02, -1.54143786e-02,  1.90579221e-02,  1.64565686e-02,
#        -7.67331868e-02, -1.64264478e-02,  5.07028326e-02, -1.21564334e-02,
#        -3.83864567e-02, -6.83228970e-02, -1.39945433e-01, -1.44791752e-02,
#        -9.69033316e-03,  7.89501071e-02, -6.45653307e-02,  4.24798802e-02,
#        -7.35233480e-04,  3.50236595e-02,  3.84418704e-02,  4.80363742e-02,
#         2.23833099e-02, -1.28537389e-02,  2.75324215e-03,  5.87296188e-02,
#         2.05988400e-02, -1.62305664e-02, -3.03814914e-02, -3.50054540e-02,
#        -9.63950977e-02, -6.29788563e-02,  2.81360280e-02,  7.38183036e-03,
#         9.52546950e-03, -3.33275422e-02, -3.43809240e-02,  1.67800039e-02,
#         3.97457853e-02, -6.05569370e-02, -1.84098631e-02, -3.73397693e-02,
#         4.43450846e-02,  2.76317261e-02, -7.24936128e-02,  6.27711741e-03,
#         3.52005512e-02, -1.64183006e-02, -1.20636551e-02,  5.98194450e-02,
#         3.90910320e-02, -7.11430609e-02,  6.66003674e-02,  1.95285995e-02,
#        -1.60702318e-03,  3.21343006e-03, -1.26375839e-01,  1.16158523e-01,
#        -1.33164199e-02, -4.91753630e-02,  1.52506847e-02, -9.00623724e-02,
#        -7.75037706e-02,  6.54386580e-02,  3.07285227e-04,  7.51396036e-03,
#        -8.43593292e-03,  3.30668408e-04,  8.32873583e-03,  1.23913931e-02,
#         2.12485790e-02,  1.96962804e-02,  6.75603971e-02,  4.99389805e-02,
#       dtype=float32)]

# %%
# TODO: Create a collection
# Choose any name you want
try: 
   collection = chroma_client.create_collection(
      name="udaplay",
      embedding_function=embedding_fn
   )
except:
   collection = chroma_client.get_collection(
      name="udaplay",
      embedding_function=embedding_fn
   )

# %% [markdown]
# ### Add documents

# %%
# Make sure you have a directory "project/starter/games"
data_dir = "games"

for file_name in sorted(os.listdir(data_dir)):
    if not file_name.endswith(".json"):
        continue

    file_path = os.path.join(data_dir, file_name)
    with open(file_path, "r", encoding="utf-8") as f:
        game = json.load(f)

    # You can change what text you want to index
    content = f"[{game['Platform']}] {game['Name']} ({game['YearOfRelease']}) - {game['Description']}"

    # Use file name (like 001) as ID
    doc_id = os.path.splitext(file_name)[0]
    print(content)
    collection.add(
        ids=[doc_id],
        documents=[content],
        # documents=['h'],
        metadatas=[game]
    )
# Out:
# [PlayStation 1] Gran Turismo (1997) - A realistic racing simulator featuring a wide array of cars and tracks, setting a new standard for the genre.
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# File /opt/venv/lib/python3.13/site-packages/chromadb/api/models/CollectionCommon.py:95, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      94 try:
# ---> 95     return func(self, *args, **kwargs)
#      96 except Exception as e:
#
# File /opt/venv/lib/python3.13/site-packages/chromadb/api/models/CollectionCommon.py:233, in CollectionCommon._validate_and_prepare_add_request(self, ids, embeddings, metadatas, documents, images, uris)
#     232     validate_record_set_for_embedding(record_set=add_records)
# --> 233     add_embeddings = self._embed_record_set(record_set=add_records)
#     234 else:
#
# File /opt/venv/lib/python3.13/site-packages/chromadb/api/models/CollectionCommon.py:555, in CollectionCommon._embed_record_set(self, record_set, embeddable_fields)
#     554         else:
# --> 555             return self._embed(input=record_set[field])  # type: ignore[literal-required]
#     556 raise ValueError(
#     557     "Record does not contain any non-None fields that can be embedded."
#     558     f"Embeddable Fields: {embeddable_fields}"
#     559     f"Record Fields: {record_set}"
#     560 )
#
# File /opt/venv/lib/python3.13/site-packages/chromadb/api/models/CollectionCommon.py:568, in CollectionCommon._embed(self, input)
#     564     raise ValueError(
#     565         "You must provide an embedding function to compute embeddings."
#     566         "https://docs.trychroma.com/guides/embeddings"
#     567     )
# --> 568 return self._embedding_function(input=input)
#
# File /opt/venv/lib/python3.13/site-packages/chromadb/api/types.py:491, in EmbeddingFunction.__init_subclass__.<locals>.__call__(self, input)
#     490 def __call__(self: EmbeddingFunction[D], input: D) -> Embeddings:
# --> 491     result = call(self, input)
#     492     assert result is not None
#
# File /opt/venv/lib/python3.13/site-packages/chromadb/utils/embedding_functions/openai_embedding_function.py:119, in OpenAIEmbeddingFunction.__call__(self, input)
#     118 # Get embeddings
# --> 119 response = self.client.embeddings.create(**embedding_params)
#     121 # Extract embeddings from response
#
# File /opt/venv/lib/python3.13/site-packages/openai/resources/embeddings.py:128, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     126     return obj
# --> 128 return self._post(
#     129     "/embeddings",
#     130     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     131     options=make_request_options(
#     132         extra_headers=extra_headers,
#     133         extra_query=extra_query,
#     134         extra_body=extra_body,
#     135         timeout=timeout,
#     136         post_parser=parser,
#     137     ),
#     138     cast_to=CreateEmbeddingResponse,
#     139 )
#
# File /opt/venv/lib/python3.13/site-packages/openai/_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1239 opts = FinalRequestOptions.construct(
#    1240     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241 )
# -> 1242 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/venv/lib/python3.13/site-packages/openai/_base_client.py:919, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     917     retries_taken = 0
# --> 919 return self._request(
#     920     cast_to=cast_to,
#     921     options=options,
#     922     stream=stream,
#     923     stream_cls=stream_cls,
#     924     retries_taken=retries_taken,
#     925 )
#
# File /opt/venv/lib/python3.13/site-packages/openai/_base_client.py:1023, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1022     log.debug("Re-raising status error")
# -> 1023     raise self._make_status_error_from_response(err.response) from None
#    1025 return self._process_response(
#    1026     cast_to=cast_to,
#    1027     options=options,
#    (...)   1031     retries_taken=retries_taken,
#    1032 )
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: YOUR_KEY. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 18
#      16 doc_id = os.path.splitext(file_name)[0]
#      17 print(content)
# ---> 18 collection.add(
#      19     ids=[doc_id],
#      20     documents=[content],
#      21     # documents=['h'],
#      22     metadatas=[game]
#      23 )
#
# File /opt/venv/lib/python3.13/site-packages/chromadb/api/models/Collection.py:80, in Collection.add(self, ids, embeddings, metadatas, documents, images, uris)
#      45 def add(
#      46     self,
#      47     ids: OneOrMany[ID],
#    (...)     57     uris: Optional[OneOrMany[URI]] = None,
#      58 ) -> None:
#      59     """Add embeddings to the data store.
#      60     Args:
#      61         ids: The ids of the embeddings you wish to add
#    (...)     77
#      78     """
# ---> 80     add_request = self._validate_and_prepare_add_request(
#      81         ids=ids,
#      82         embeddings=embeddings,
#      83         metadatas=metadatas,
#      84         documents=documents,
#      85         images=images,
#      86         uris=uris,
#      87     )
#      89     self._client._add(
#      90         collection_id=self.id,
#      91         ids=add_request["ids"],
#    (...)     97         database=self.database,
#      98     )
#
# File /opt/venv/lib/python3.13/site-packages/chromadb/api/models/CollectionCommon.py:98, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      96 except Exception as e:
#      97     msg = f"{str(e)} in {name}."
# ---> 98     raise type(e)(msg).with_traceback(e.__traceback__)
#
# TypeError: APIStatusError.__init__() missing 2 required keyword-only arguments: 'response' and 'body'
